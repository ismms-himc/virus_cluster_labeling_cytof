# %%
import numpy as np
import scipy
import pandas as pd

spearmanr = scipy.stats.spearmanr

# %%
np.random.seed(1234321)

# %%
spearmanr([1,2,3,4,5],[5,6,7,8,7])
# Out:
# SpearmanrResult(correlation=0.82078268166812329, pvalue=0.088587005313543812)

# %%
df_labeled = pd.read_csv('../data_mats/labeled_data.csv', index_col=0)

# %%
df_labeled
# Out:
#                                CCR4      CCR5      CCR6      CCR7     CD11b  \
# b_cell_memory_1            0.206923  0.139952  0.541482  0.279959  0.322815
# b_cell_naive_1             0.679484  0.130796  0.460357  0.378619  0.290657
# b_cell_naive_2             0.267300  0.208335  0.625946  0.169433  0.383113
# b_cell_naive_3             0.231755  0.157186  0.536468  0.125129  0.336918
# b_cell_naive_4             0.188370  0.087694  0.567337  0.459391  0.317875
# b_cell_plasmablast_1       0.297974  0.092917  0.209718  0.403448  0.221408
# b_cell_transitional_1      0.203292  0.112569  0.479848  0.306262  0.295465
# b_cell_transitional_2      0.204851  0.112608  0.492944  0.312689  0.298371
# basophil_1                 0.126051  0.158646  0.070014  0.163327  0.543515
# cd14_cd16_monocyte_1       0.192098  0.174339  0.095895  0.226476  0.630568
# cd14_cd16_monocyte_2       0.196188  0.272340  0.072784  0.122446  0.748945
# ...

# %%
df_labeled = df_labeled.transpose()

# %%
series_1 = df_labeled['b_cell_naive_1']
series_2 = df_labeled['ilc_1']

# %%
spearmanr(series_1, series_2)
# Out:
# SpearmanrResult(correlation=0.25699383594120434, pvalue=0.12466148860353625)

# %%
'something_1'.split('_')[:-1]
# Out:
# ['something']
